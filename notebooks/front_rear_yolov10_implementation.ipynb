# %%
# !python --version
# Out:
# Python 3.10.15

# %% [markdown]
# ### Download repo and installing required packages

# %%
# !git clone https://github.com/THU-MIG/yolov10.git

# %%
cd yolov10
# Out:
# /media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10

# %%
# !pip install .
# Out:
# Processing /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.5.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# ...
#   Using cached torchvision-0.20.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# ...

# %% [markdown]
# ### Downloading pretrained weights

# %%
# import os
# import urllib.request

# # Create a directory for the weights in the current working directory
# weights_dir = os.path.join(os.getcwd(), "weights")
# os.makedirs(weights_dir, exist_ok=True)

# # URLs of the weight files
# urls = [
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
# ]

# # Download each file
# for url in urls:
#     file_name = os.path.join(weights_dir, os.path.basename(url))
#     urllib.request.urlretrieve(url, file_name)
#     print(f"Downloaded {file_name}")
# Out:
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10n.pt
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10s.pt
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10m.pt
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10b.pt
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10x.pt
# Downloaded /media/nsl3090-3/hdd1/Badhon/Part_1/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10l.pt

# %% [markdown]
# # Inference using pretrained model

# %%
# !pip install huggingface-hub

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10n.pt source=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/test_images/1.jpg
# Out:
# /home/nsl3090-3/anaconda3/envs/ob_yolo/lib/python3.10/site-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# # Train Custom Model

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10n.pt data=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/data.yaml

# %%
# !yolo task=detect mode=train epochs=100 batch=32 plots=True model=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10/weights/yolov10n.pt data=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/data.yaml device=0,1 amp=True
# Out:
# /home/nsl3090-3/anaconda3/envs/ob_yolo/lib/python3.10/site-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# # Inference

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10/runs/detect/train2/weights/best.pt source=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/test_images_1/car_2.jpg
# Out:
# /home/nsl3090-3/anaconda3/envs/ob_yolo/lib/python3.10/site-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %% [markdown]
# # Inference on Video

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/yolov10/runs/detect/train2/weights/best.pt source=/media/nsl3090-3/hdd1/Badhon/Part_2/YOLOv10-Custom-Object-Detection/b.mp4
# Out:
# /home/nsl3090-3/anaconda3/envs/ob_yolo/lib/python3.10/site-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...
